# %%
# !pip install torch torchvision opencv-python pandas numpy chess
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 116.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for chess: filename=chess-1.11.2-py3-none-any.whl size=147775 sha256=7c3122b7f4284b10b45369de033eb6cfc71d82b6520e306a675d44b4963ec7e9
#   Stored in directory: /root/.cache/pip/wheels/83/1f/4e/8f4300f7dd554eb8de70ddfed96e94d3d030ace10c5b53d447
# Successfully built chess
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# Force change to a known valid directory (root) in case the current working directory is invalid.
os.chdir('/')

# Now, ensure the current directory is /content
# If we are already in /content, this does nothing.
if os.getcwd() != '/content':
  os.chdir('/content')

# Unzip the project to /content/chessboard-project
# !unzip /content/drive/MyDrive/chessboard-project-colab.zip -d /content/
# !unzip /content/drive/MyDrive/final_dataset.zip -d /content/chessboard-project/

# !ls
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game6_frame_030504_r1_c3.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game6_frame_032832_r1_c3.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game7_frame_001196_r0_c2.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game7_frame_001196_r2_c3.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game7_frame_004952_r2_c0.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game7_frame_004952_r2_c3.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game7_frame_006944_r2_c0.jpg
#   inflating: /content/chessboard-project-colab/final_dataset/val/black_bishop/game7_frame_006944_r2_c3.jpg
# ...

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
# Out:
# Device: cuda

# %%
# !python /content/chessboard-project-colab/train_colab.py
# Out:
# ...
# Run started: 2026-01-16 16:45:12 (run_id=20260116_164512)
# Saving to folder: /content/drive/MyDrive/chessboard_models
# Model: /content/drive/MyDrive/chessboard_models/chess_model_20260116_164512.pth
# Checkpoint: /content/drive/MyDrive/chessboard_models/checkpoint_last_20260116_164512.pth
# Curves: /content/drive/MyDrive/chessboard_models/learning_curves_20260116_164512.png
# Log: /content/drive/MyDrive/chessboard_models/train_log_20260116_164512.txt
# Device: cuda
# ...
# Datasets loaded: {'train': 40507, 'val': 5033}
# Testing one train batch...
# First batch OK: torch.Size([32, 3, 224, 224]) torch.Size([32])
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|##########| 44.7M/44.7M [00:00<00:00, 218MB/s]
# Epoch 1/20 | train Loss: 0.6166 Acc: 0.9157
# Epoch 1/20 | val Loss: 0.1658 Acc: 0.9696
# Saved checkpoint: /content/drive/MyDrive/chessboard_models/checkpoint_last_20260116_164512.pth
# ...
